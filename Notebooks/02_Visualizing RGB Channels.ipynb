# %% [markdown]
# # RGB colorspace

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# ### Read in an image

# %%
# Read in the image
image = mpimg.imread('images/wa_state_highway.jpg')

plt.imshow(image)

# %% [markdown]
# ### RGB channels
#
# Visualize the levels of each color channel. Pay close attention to the traffic signs!

# %%
# Isolate RGB channels
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

# Visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.set_title('R channel')
ax1.imshow(r, cmap='hot')
ax2.set_title('G channel')
ax2.imshow(g, cmap='summer')
ax3.set_title('B channel')
ax3.imshow(b, cmap='bone')

## Which area has the lowest value for red? What about for blue?

# %%
import numpy as np
max_red = np.amax(r)
max_blue = np.amax(b)

print("Max Red",max_red), print("Max Blue",max_blue)
# Out:
# Max Red 255
# Max Blue 255
# (None, None)

# %%
x = 20
y = 30
print(r[y, x])
# Out:
# 113

# %%
r.shape, r.shape[0], r.shape[1]
# Out:
# ((3088, 4700), 3088, 4700)

# %%
x_max = 0
y_max = 0
count_max = 0
area_max = 0

for y_1 in range(r.shape[1]):
    for x_1 in range(r.shape[0]):    
        if r[x_1, y_1] == max_red:
            count_max +=1
            
for y_2 in range(r.shape[1]):
    for x_2 in range(r.shape[0]):    
        if r[x_2, y_2] == max_red:
            x_max = x_2
            y_max = y_2
            break

# I wanted to find the biggest area of maximum intensity
# the idea was to consider 1 pixes as 1 and I wanted to 
# find cluster of pixels aggregated together with maxi
for y in range(r.shape[1]):
    for x in range(r.shape[0]):    
        if r[x, y] == max_red:
            area_max += 1
            start = y+1
            for k in range(start, r.shape[0]):
                if r[x, y] == max_red:
                    area_max += 1
                else:
                    start = 
                    continue
        
print("There are "+str(count_max)+" pixes with the more intense colour. One of them is", (x_max, y_max))
# Out:
# There are 4758 pixes with the more intense colour. One of them is (2293, 4178)

# %%
r[2293, 4178]
# Out:
# 255
